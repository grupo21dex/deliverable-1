# %% [markdown]
# <a href="https://colab.research.google.com/github/grupo21dex/deliverable-1/blob/main/Din%C3%A2mica_NYFlights_Grupo21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("nyflights.csv")

# %%
df.head(5)
# Out:
#    Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 0           1  2013      1    1     517.0             515        2.0
# 1           2  2013      1    1     533.0             529        4.0
# 2           3  2013      1    1     542.0             540        2.0
# 3           4  2013      1    1     544.0             545       -1.0
# 4           5  2013      1    1     554.0             600       -6.0
#
#    arr_time  sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 0     830.0             819       11.0      UA    1545  N14228    EWR  IAH
# 1     850.0             830       20.0      UA    1714  N24211    LGA  IAH
# 2     923.0             850       33.0      AA    1141  N619AA    JFK  MIA
# 3    1004.0            1022      -18.0      B6     725  N804JB    JFK  BQN
# 4     812.0             837      -25.0      DL     461  N668DN    LGA  ATL
#
#    air_time  distance  hour  minute            time_hour
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19558 entries, 0 to 19557
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      19558 non-null  int64
#  1   year            19558 non-null  int64
#  2   month           19558 non-null  int64
#  3   day             19558 non-null  int64
#  4   dep_time        19380 non-null  float64
#  5   sched_dep_time  19558 non-null  int64
#  6   dep_delay       19380 non-null  float64
#  7   arr_time        19371 non-null  float64
#  8   sched_arr_time  19558 non-null  int64
#  9   arr_delay       19325 non-null  float64
#  10  carrier         19558 non-null  object
#  11  flight          19558 non-null  int64
#  12  tailnum         19491 non-null  object
#  13  origin          19558 non-null  object
#  14  dest            19558 non-null  object
#  15  air_time        19325 non-null  float64
#  16  distance        19558 non-null  int64
# ...

# %%
#Etapa 1

df_filtro = df[df["dep_delay"]>120]
df_filtro.head()
# Out:
#      Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 151         152  2013      1    1     848.0            1835      853.0
# 218         219  2013      1    1     957.0             733      144.0
# 268         269  2013      1    1    1114.0             900      134.0
# 491         492  2013      1    1    1540.0            1338      122.0
# 649         650  2013      1    1    1815.0            1325      290.0
#
#      arr_time  sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 151    1001.0            1950      851.0      MQ    3944  N942MQ    JFK  BWI
# 218    1056.0             853      123.0      UA     856  N534UA    EWR  BOS
# 268    1447.0            1222      145.0      UA    1086  N76502    LGA  IAH
# 491    2020.0            1825      115.0      B6     705  N570JB    JFK  SJU
# 649    2120.0            1542      338.0      EV    4417  N17185    EWR  OMA
#
#      air_time  distance  hour  minute            time_hour
# ...

# %%
df_describe = df_filtro["dep_delay"].describe().T.copy()
df_describe
# Out:
# count     296.000000
# mean      188.300676
# std       113.154675
# min       121.000000
# 25%       135.000000
# 50%       157.000000
# 75%       198.250000
# max      1301.000000
# Name: dep_delay, dtype: float64

# %%
df_describe = df_filtro.describe().T.copy()
df_describe
# Out:
#                 count          mean          std     min      25%      50%  \
# Unnamed: 0      296.0  10881.351351  6096.514584   152.0  4633.00  11849.0
# year            296.0   2013.000000     0.000000  2013.0  2013.00   2013.0
# month           296.0      1.000000     0.000000     1.0     1.00      1.0
# day             296.0     12.780405     6.998965     1.0     6.00     14.0
# dep_time        296.0   1679.192568   552.710308     2.0  1306.50   1837.5
# sched_dep_time  296.0   1497.783784   450.935758   558.0  1126.75   1619.0
# dep_delay       296.0    188.300676   113.154675   121.0   135.00    157.0
# arr_time        295.0   1426.000000   819.473043     2.0  1001.50   1645.0
# sched_arr_time  296.0   1687.510135   484.835425    36.0  1332.00   1820.0
# arr_delay       293.0    184.965870   114.190115    65.0   133.00    160.0
# flight          296.0   2745.057432  1823.855635     7.0   622.25   3490.0
# ...

# %%
df_describe["amplitude"] = df_describe['max'] - df_describe['min']
df_describe["variância"] = df_describe['std'] **2
df_describe
# Out:
#                 count          mean          std     min      25%      50%  \
# Unnamed: 0      296.0  10881.351351  6096.514584   152.0  4633.00  11849.0
# year            296.0   2013.000000     0.000000  2013.0  2013.00   2013.0
# month           296.0      1.000000     0.000000     1.0     1.00      1.0
# day             296.0     12.780405     6.998965     1.0     6.00     14.0
# dep_time        296.0   1679.192568   552.710308     2.0  1306.50   1837.5
# sched_dep_time  296.0   1497.783784   450.935758   558.0  1126.75   1619.0
# dep_delay       296.0    188.300676   113.154675   121.0   135.00    157.0
# arr_time        295.0   1426.000000   819.473043     2.0  1001.50   1645.0
# sched_arr_time  296.0   1687.510135   484.835425    36.0  1332.00   1820.0
# arr_delay       293.0    184.965870   114.190115    65.0   133.00    160.0
# flight          296.0   2745.057432  1823.855635     7.0   622.25   3490.0
# ...

# %% [markdown]
# O comportamento médio foi 188.300676
# A variância foi 1.280398e+04

# %%
#Etapa 2
df_atraso = df[df["dep_delay"]>5]
df_atraso
# Out:
#        Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 25             26  2013      1    1     608.0             600        8.0
# 26             27  2013      1    1     611.0             600       11.0
# 31             32  2013      1    1     623.0             610       13.0
# 41             42  2013      1    1     632.0             608       24.0
# 47             48  2013      1    1     644.0             636        8.0
# ...           ...   ...    ...  ...       ...             ...        ...
# 19535       19536  2013      1   23    1324.0            1315        9.0
# 19550       19551  2013      1   23    1351.0            1345        6.0
# 19551       19552  2013      1   23    1352.0            1250       62.0
# 19552       19553  2013      1   23    1352.0            1335       17.0
# 19557       19558  2013      1   23    1357.0            1329       28.0
#
#        arr_time  sched_arr_time  arr_delay carrier  flight tailnum origin  \
# ...

# %%
df_atraso["dest"].value_counts().head(10)
# Out:
# ORD    223
# FLL    214
# MCO    205
# BOS    193
# ATL    169
# LAX    166
# MIA    157
# CLT    145
# DCA    136
# SFO    136
# Name: dest, dtype: int64

# %%
df_atraso["dest"].value_counts().tail(10)
# Out:
# BHM    5
# OAK    5
# SJC    4
# CAE    4
# CAK    4
# AVL    1
# BZN    1
# EYW    1
# PSP    1
# HDN    1
# Name: dest, dtype: int64

# %% [markdown]
# Os 5 destinos que tiveram mais atrasos na partida são:
# ORD = 223;
# FLL = 214;
# MCO = 205;
# BOS = 193;
# ATL = 169

# %%
#Etapa 3

lista_destino = ['ORD', 'FLL', 'MCO', 'BOS', 'ATL']
df_med_piores = df_atraso[df_atraso.dest.isin(lista_destino)]
df_med_piores
# Out:
#        Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 25             26  2013      1    1     608.0             600        8.0
# 47             48  2013      1    1     644.0             636        8.0
# 70             71  2013      1    1     709.0             700        9.0
# 85             86  2013      1    1     732.0             645       47.0
# 96             97  2013      1    1     749.0             710       39.0
# ...           ...   ...    ...  ...       ...             ...        ...
# 19474       19475  2013      1   23    1156.0            1130       26.0
# 19498       19499  2013      1   23    1242.0            1230       12.0
# 19522       19523  2013      1   23    1312.0            1300       12.0
# 19550       19551  2013      1   23    1351.0            1345        6.0
# 19551       19552  2013      1   23    1352.0            1250       62.0
#
#        arr_time  sched_arr_time  arr_delay carrier  flight tailnum origin  \
# ...

# %%
df_med_piores.describe()
# Out:
#          Unnamed: 0    year   month          day     dep_time  sched_dep_time  \
# count   1004.000000  1004.0  1004.0  1004.000000  1004.000000     1004.000000
# mean    9764.350598  2013.0     1.0    11.600598  1498.165339     1448.915339
# std     5905.549549     0.0     0.0     6.787975   457.795962      446.609900
# min       26.000000  2013.0     1.0     1.000000    10.000000      558.000000
# 25%     4093.250000  2013.0     1.0     5.000000  1154.500000     1123.000000
# 50%    10332.000000  2013.0     1.0    12.000000  1557.000000     1529.000000
# 75%    14782.250000  2013.0     1.0    17.000000  1830.250000     1800.000000
# max    19552.000000  2013.0     1.0    23.000000  2351.000000     2258.000000
#
#          dep_delay     arr_time  sched_arr_time    arr_delay       flight  \
# count  1004.000000  1004.000000     1004.000000  1003.000000  1004.000000
# mean     36.779880  1600.618526     1614.373506    33.000997  1279.254980
# ...

# %%
df_med_piores['velocidade média'] = df_med_piores["distance"]/df_med_piores["air_time"]
df_med_piores
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 25             26  2013      1    1     608.0             600        8.0
# 47             48  2013      1    1     644.0             636        8.0
# 70             71  2013      1    1     709.0             700        9.0
# 85             86  2013      1    1     732.0             645       47.0
# 96             97  2013      1    1     749.0             710       39.0
# ...           ...   ...    ...  ...       ...             ...        ...
# ...

# %%
df_med_piores['velocidade média'].mean()
# Out:
# 6.0990621282936175

# %%
df_med_piores.groupby('dest').agg({'velocidade média':'mean'})
# Out:
#       velocidade média
# dest
# ATL           6.173417
# BOS           4.984730
# FLL           6.781675
# MCO           6.629831
# ORD           5.859147

# %% [markdown]
# A velocidade média dos 5 destinos que mais ocorrem atrasos é de:
# ATL = 6.173417
# BOS = 4.984730
# FLL = 6.781675
# MCO =	6.629831
# ORD =	5.859147
